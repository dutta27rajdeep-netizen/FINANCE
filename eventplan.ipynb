# %% [markdown]
# # 25th Anniversary Celebration Guest List & Event Planning
# ## Tapan Ghosh & Dhanashree Ghosh
# ### South City Main Banquet and Evening Banquet
# ---
# **Event Dates:** 24-25 April 2026
# **Prepared for:** Professional Event Planning & Coordination

# %%
import pandas as pd
import numpy as np
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side
from openpyxl.worksheet.datavalidation import DataValidation
from openpyxl.formatting.rule import CellIsRule, ColorScaleRule
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Step 1: Parse and Organize Guest Data

# %%
# Ghosh Family - 51 expected
_ghosh_family = [
    {"name": "Annapurna Ghosh", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Parna Papai Ibhan", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Tapati di (Maman sasuri)", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Debika Gitasree", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Satyen Parbat (chotomama)", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sailen Parbat (mejomama)", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Sangeeta Shubhomay Krishiv", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "Yes"},
    {"name": "Bado Mashi Bony baba", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Achintya da (Bado mama) - family", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "No"},
    {"name": "Aarti mashi Chandi didi", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Suchitra Ghosh Parna Bua", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Gita Pati family", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Chitra Chandan Misthi", "category": "Ghosh Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sipra Ghosh", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Anima Ghosh", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "No"},
    {"name": "Jayanti Ghosh Mumbai", "category": "Ghosh Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Bishu Ghosh", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "No"},
    {"name": "Ranu Pan Bappa", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Shatabdi family", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Ophelia family", "category": "Ghosh Family", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Nami pishi", "category": "Ghosh Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
]

print(f"Ghosh Family entries created: {len(_ghosh_family)}")
# Out:
# Ghosh Family entries created: 21

# %%
# Deshpande Family - 25 expected
_deshpande_family = [
    {"name": "Kumud mavshi Vibha mavshi Shraddha", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Rohit Mugdha Saee", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Pushpa mavshi", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Chotu Ashwini Vedika", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Prasad dada Lata Atharva", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Sachin Sarita Sree Sanvi Mami", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Leena Vinod Mohit", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Vishakha Amogh Mahati", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Atul dada Gouri Aditya", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Prasad Rucha Rewa Zoya", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Jyoti atya Arunkaka", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Kedar Lily Ashok Felix", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "Yes"},
    {"name": "Lily brother family", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Omkar", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Abhishek Atharva Manasi", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Vijaymama Rekhamami", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Aniket Pallavi Ruhi", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Shraddha Amit sanay Sannidhi", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Vrinda Salil Sanjib", "category": "Deshpande Family", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Tripti Galgali Hubli", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Laxmikant Popat", "category": "Deshpande Family", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
]

print(f"Deshpande Family entries created: {len(_deshpande_family)}")
# Out:
# Deshpande Family entries created: 21

# %%
# Shriya & Tapan Friends - 40 expected
_shriya_tapan_friends = [
    {"name": "Anil Pandya", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Ankur Pandya", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Asha Pandya", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Bijayalaxmi Dash", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Chandan Rai", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Debaprasad Srivastav", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Deepak Panda", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sumit Jha Swati", "category": "Shriya-Tapan Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Anshuman Verma", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Gagan Yadav", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Jignesh Raza", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Karun Rao", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Kaustubh Pandey", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Mukesh Kasarla", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Neeraj Kumar", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Nikhil Yogi", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Panu Pandey", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Praveen Tiwari", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Rajesh Srivastava", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Rajshekar Rao", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Rangesh Roy", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Ravi Ravi", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Ravi Teja", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Rohit Pandey", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sai Chinnakonda", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sandeep Handa", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sandipan Chakraborty Ananya", "category": "Shriya-Tapan Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sanjay Sinha", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sankar Raman", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sapan Bhattacharya", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Satya Ramendar", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sharad Singh", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sharad Mahadeva Ravi", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Shashankaanand Srivastava", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Shiva Sharath", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sidharth Verma", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Sidharth Rao", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Siddharth Saxena", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Siddhartha Mallick", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Srinath Jaiswal", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Srivinas Raman", "category": "Shriya-Tapan Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
]

print(f"Shriya & Tapan Friends entries created: {len(_shriya_tapan_friends)}")
# Out:
# Shriya & Tapan Friends entries created: 41

# %%
# Shriya Friends - 15 expected
_shriya_friends = [
    {"name": "Abha Jayanth Aditya Arjun", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "Yes"},
    {"name": "Akshara Chethan", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Amarta Viraj Mira", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Amer Sai Shreya Akshara", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "Yes"},
    {"name": "Ameya Krishna", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Ankita Rahul", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Anjali Abhinav Zara", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Aparna Suraj Ishaan", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Archana Prabhakar", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Aritri Ray", "category": "Shriya Friends", "attending": "Yes", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Aruna Mohan Shriya", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Arunima Varun Adya", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Asha Ramakrishnan Aditya", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Ashameera Naveen Dhruva", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Ashima Rajeev", "category": "Shriya Friends", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
]

print(f"Shriya Friends entries created: {len(_shriya_friends)}")
# Out:
# Shriya Friends entries created: 15

# %%
# Dentist Guests - 64 entries (190 expected)
_dentist_guests = [
    {"name": "Dr Subhasis Ghosh / Srabani Dasgupta", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Dr Roo Biswas Roy", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Sanjay Kumar", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Renuka Tulsiyan Garg / Sanjeev Garg", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Dr Anuradha / Sukrit Bose", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Sneha Tapadiya Saurabh", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Shreya Bhowmik", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Aastha Todi & Rishi Modi", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "Yes"},
    {"name": "Dr Palak Shah Vimal", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Dr Akash", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Romita De Debi", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Sankarshan Chowdhury", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Sujay Kr Sahoo Dr Ishita", "category": "Dentists", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Kamlesh Kothari", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Aditya Mitra Dr Swati Mitra family", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Sankalp Taparia Roli family", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "Yes"},
    {"name": "Dr Shilpi Malhotra family", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Sneha Seksaria family", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Dr Dipanjana Dr Swagato family", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 3, "rsvp": "Yes"},
    {"name": "Dr Saptarshi Dutta Dr Paromita", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Dr Simrat Kaur Family", "category": "Dentists", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Kanupriya Goyal", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Soham Chatterjee", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Rit Ipsita Chowdhury", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Ayan Majumder", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Saurav Mukherjee", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Debashish Bera", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Siddharth Nath", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Nirmalya Bhattacharya", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Sohail Ali", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Anirban Bhattacharya", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Sujoy Dutta", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Raju Biswas", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Radha Hariharan", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr P J Mustafi", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Utpal Burman", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Kamal Dutta", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr J K Singh", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr G R Ashok", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Amit Roy", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Asif Shabir", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Shitangshu Ghosh / Dr Shounak Ghosh", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Abhijit Mahata / Dr Samhita Mahata", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Anant Pal Singh", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr D P Das", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Souparna Roy", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Joydeb Kundu", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Angshuman Bhattacharya", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Bhaskar Mukherjee", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Abantika Mukherjee", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Shiv Bhushan Pandey Dr Priyanka", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Atisha Singh", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Abhishek Singh", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Aniruddha Kundu", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Uday Kundu", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Aniket Chaterjee", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Atul Tondan", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Ashish Taru Saha", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Biswajit Biswas", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr B K Biswas", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Debdeep Chakraborty", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Shubhrangshu Ganguly", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Samiran Ghosh", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Amit Nandy", "category": "Dentists", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
]

print(f"Dentist Guests entries created: {len(_dentist_guests)}")
# Out:
# Dentist Guests entries created: 64

# %%
# Out Station Doctors and Invitees
_out_station_doctors = [
    {"name": "Dr Sudheer KH / Dr Archana", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Sudha Malpani", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Aditya Kulkarni / Minu", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Nikhil Churi", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Ashish / Dr Shilpa", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Aman Kapoor", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Shanti Swaroop Mittal", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Vidya Nayak", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Tarun Gera", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Idris Jhariwala", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Nimish Shah", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Nitin Baidya", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Katara / Amit Katara", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Eric Liu", "category": "Out Station Doctors", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Kunal Banka", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Sachindeep Singh", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Yazad Gandhi", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Neel BhatWadekar", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Dr Apoorva Gupta", "category": "Out Station Doctors", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Dr Dhruv Arora", "category": "Out Station Doctors", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
]

print(f"Out Station Doctors entries created: {len(_out_station_doctors)}")
# Out:
# Out Station Doctors entries created: 20

# %%
# South City Invitations
_south_city_invitations = [
    {"name": "Amal Kumar Sanyal / Gopa Sanyal", "category": "South City Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Jay Srijita Sanyal", "category": "South City Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Pranav Ila Mukherjee", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Priyanka Sangeet Kian Bhowmick", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Mandira Danda (Kakima)", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dr Sudipta Dr Debasish", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Dr Shaon Anubriti Mithai", "category": "South City Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Palash Soma di", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Dipshikha Maitra", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Soutrik Mukherjee", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sayantini", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Uma Mitra", "category": "South City Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
]

print(f"South City Invitations entries created: {len(_south_city_invitations)}")
# Out:
# South City Invitations entries created: 12

# %%
# ADC and Associates
_adc_associates = [
    {"name": "Subhankar Kakali Shounak", "category": "ADC and Associates", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Jahangir Shahina Ahana", "category": "ADC and Associates", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Priyanka Amit Anupriya", "category": "ADC and Associates", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Siddhartha da Sumita Srijani Shyamlal", "category": "ADC and Associates", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "Yes"},
    {"name": "Niladri Majumder family", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sushmita Ghosh family", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sumona", "category": "ADC and Associates", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Sameer Ganguly", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sukdeb", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Shankar da", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Kanupriya Khaitan", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Manas Chowdhury", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Somani ji", "category": "ADC and Associates", "attending": "No", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 0, "rsvp": "No"},
    {"name": "Ardhendu", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Ramprakash Jaiswal", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Omprakash Moti", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Ayan Banerjee", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Shirshendu", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Aniruddha", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Mousam Bohra", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "D S Ganguly", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Souvik", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Anshuman Gupta", "category": "ADC and Associates", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
]

print(f"ADC and Associates entries created: {len(_adc_associates)}")
# Out:
# ADC and Associates entries created: 23

# %%
# Other Invitations
_other_invitations = [
    {"name": "Asma", "category": "Other Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Pinky", "category": "Other Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Jamini", "category": "Other Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Jamini family", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Shikha", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Babu", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Tumpa", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Manoj", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Brij", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Tapas Mali", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Kajal Da", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Pradip da massage", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Lakhi beautician", "category": "Other Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Arjun family", "category": "Other Invitations", "attending": "Both", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "Yes"},
    {"name": "Bapi da", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Lawyer", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Toton da", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Aamir Da", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sagid da", "category": "Other Invitations", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
]

print(f"Other Invitations entries created: {len(_other_invitations)}")
# Out:
# Other Invitations entries created: 19

# %%
# ADC Patients
_adc_patients = [
    {"name": "Bibha Saha", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Anurag Jhawar and family", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sushil Murarka and family", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 2, "rsvp": "No"},
    {"name": "Lalit Bhalotia", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Gurudeb", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Amrik Singh Saini family", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sanjay Patodiya", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "N K Sarda", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Nilratan Mondal", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Avigyan Ghosh", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Suman De Mandira Chaterjee", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Sangeeta Bhakti Khemka", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Himshikha Palit", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Manohar lal Agarwal", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Bharat Poddar", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Pradip Dutta", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
    {"name": "Chandranath Sen", "category": "ADC Patients", "attending": "Evening", "veg": "NA", "alcohol": "NA", "rooms": "NA", "room_type": "NA", "accompanying": 1, "rsvp": "No"},
]

print(f"ADC Patients entries created: {len(_adc_patients)}")
# Out:
# ADC Patients entries created: 17

# %%
# Combine all guest data
all_guests = (
    _ghosh_family + _deshpande_family + _shriya_tapan_friends + _shriya_friends +
    _dentist_guests + _out_station_doctors + _south_city_invitations + _adc_associates +
    _other_invitations + _adc_patients
)

# Create DataFrame
df = pd.DataFrame(all_guests)

# Add additional columns for event planning
df['S.No'] = range(1, len(df) + 1)
df['Notes'] = ''
df['Estimated Headcount'] = 1  # Will be calculated based on family size
df['Transportation Mode'] = 'NA'
df['Transportation Notes'] = ''
df['Per Person Budget'] = 0  # To be filled later
df['Special Requests'] = ''
df['Contact Person'] = ''
df['Contact Phone'] = ''
df['Contact Email'] = ''

# Reorder columns
cols = ['S.No', 'name', 'category', 'attending', 'veg', 'alcohol', 'rooms', 'room_type', 'accompanying',
        'rsvp', 'Transportation Mode', 'Transportation Notes',
        'Per Person Budget', 'Special Requests', 'Contact Person', 'Contact Phone', 
        'Contact Email', 'Notes']

df = df[cols]

# Rename columns for display
df.columns = ['S.No', 'Guest Name', 'Category', 'Event Attendance', 'Food Choice', 
              'Alcohol Preference', 'Rooms Required', 'Room Type', 'Accompanying Count', 'RSVP Status',
              'Transportation Mode', 'Transportation Notes', 'Per Person Budget',
              'Special Requests', 'Contact Person', 'Contact Phone', 'Contact Email', 'Notes']

print(f"\nTotal Guest Records Created: {len(df)}")
print(f"\nDataFrame Preview:")
print(df.head(10))
# Out:
# Total Guest Records Created: 253
#
# DataFrame Preview:
#    S.No                        Guest Name      Category Event Attendance  \
# 0     1                   Annapurna Ghosh  Ghosh Family             Both
# 1     2                 Parna Papai Ibhan  Ghosh Family             Both
# 2     3          Tapati di (Maman sasuri)  Ghosh Family          Evening
# 3     4                   Debika Gitasree  Ghosh Family             Both
# 4     5         Satyen Parbat (chotomama)  Ghosh Family             Both
# 5     6          Sailen Parbat (mejomama)  Ghosh Family             Both
# 6     7        Sangeeta Shubhomay Krishiv  Ghosh Family             Both
# 7     8              Bado Mashi Bony baba  Ghosh Family             Both
# 8     9  Achintya da (Bado mama) - family  Ghosh Family          Evening
# 9    10           Aarti mashi Chandi didi  Ghosh Family          Evening
#
#   Food Choice Alcohol Preference Rooms Required Room Type  Accompanying Count  \
# ...

# %% [markdown]
# ## Step 2: Create Excel File with Formatting and Data Validation

# %%
# Create a new workbook
wb = Workbook()
ws = wb.active
ws.title = "Guest List"

# Define colors
color_header = "1F4E78"  # Dark Blue
color_yes_green = "C6EFCE"  # Light Green
color_no_red = "FFC7CE"  # Light Red
color_both_gold = "FFF2CC"  # Light Gold
color_evening_orange = "FFE699"  # Light Orange
color_no_attend_gray = "E2EFDA"  # Light Gray

# Define fonts and styles
header_font = Font(bold=True, color="FFFFFF", size=11)
header_fill = PatternFill(start_color=color_header, end_color=color_header, fill_type="solid")
header_alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)

border_style = Border(
    left=Side(style='thin'),
    right=Side(style='thin'),
    top=Side(style='thin'),
    bottom=Side(style='thin')
)

print("Excel workbook initialized with styling...")
# Out:
# Excel workbook initialized with styling...

# %%
# Write headers
for col_num, header in enumerate(df.columns, 1):
    cell = ws.cell(row=1, column=col_num)
    cell.value = header
    cell.font = header_font
    cell.fill = header_fill
    cell.alignment = header_alignment
    cell.border = border_style

# Set column widths - Updated to match new columns
column_widths = {
    'A': 6,   # S.No
    'B': 30,  # Guest Name
    'C': 20,  # Category
    'D': 16,  # Event Attendance
    'E': 14,  # Food Choice
    'F': 16,  # Alcohol Preference
    'G': 15,  # Rooms Required
    'H': 12,  # Room Type
    'I': 16,  # Accompanying Count
    'J': 14,  # RSVP Status
    'K': 16,  # Transportation Mode
    'L': 18,  # Transportation Notes
    'M': 16,  # Per Person Budget
    'N': 16,  # Special Requests
    'O': 14,  # Contact Person
    'P': 14,  # Contact Phone
    'Q': 18,  # Contact Email
    'R': 20   # Notes
}

for col, width in column_widths.items():
    ws.column_dimensions[col].width = width

print("Headers and column widths configured...")
# Out:
# Headers and column widths configured...

# %%
# Data validation lists
attending_list = ["Both", "Evening", "No"]
veg_list = ["Yes", "No", "NA"]
alcohol_list = ["Yes", "No", "NA"]
rooms_list = [str(i) for i in range(0, 11)]  # 0-10 rooms
rsvp_list = ["Yes", "No", "Pending"]
transport_list = ["Car", "Taxi", "Flight", "Train", "Own Transport", "NA"]

print("Data validation lists prepared...")
# Out:
# Data validation lists prepared...

# %%
# Write data and apply formatting
row_mapping = {}  # To track row numbers for each record

for row_num, (idx, row) in enumerate(df.iterrows(), 2):
    row_mapping[idx] = row_num
    
    # Prepare row data - directly from DataFrame
    row_data = [
        row['S.No'],
        row['Guest Name'],
        row['Category'],
        row['Event Attendance'],
        row['Food Choice'],
        row['Alcohol Preference'],
        row['Rooms Required'],
        row['Room Type'],
        row['Accompanying Count'],
        row['RSVP Status'],
        row['Transportation Mode'],
        row['Transportation Notes'],
        row['Per Person Budget'],
        row['Special Requests'],
        row['Contact Person'],
        row['Contact Phone'],
        row['Contact Email'],
        row['Notes']
    ]
    
    # Write cells
    for col_num, value in enumerate(row_data, 1):
        cell = ws.cell(row=row_num, column=col_num)
        cell.value = value
        cell.border = border_style
        cell.alignment = Alignment(horizontal="left", vertical="center", wrap_text=True)
        
        # Apply conditional formatting based on column
        if col_num == 4:  # Event Attendance
            if value == "Both":
                cell.fill = PatternFill(start_color=color_both_gold, end_color=color_both_gold, fill_type="solid")
            elif value == "Evening":
                cell.fill = PatternFill(start_color=color_evening_orange, end_color=color_evening_orange, fill_type="solid")
            elif value == "No":
                cell.fill = PatternFill(start_color=color_no_attend_gray, end_color=color_no_attend_gray, fill_type="solid")
        
        elif col_num == 5:  # Food Choice
            if value == "NA":
                cell.fill = PatternFill(start_color="E2EFDA", end_color="E2EFDA", fill_type="solid")
        
        elif col_num == 6:  # Alcohol Preference
            if value == "NA":
                cell.fill = PatternFill(start_color="E2EFDA", end_color="E2EFDA", fill_type="solid")
        
        elif col_num == 10:  # RSVP Status
            if value == "Yes":
                cell.fill = PatternFill(start_color=color_yes_green, end_color=color_yes_green, fill_type="solid")
            elif value == "No":
                cell.fill = PatternFill(start_color=color_no_red, end_color=color_no_red, fill_type="solid")

print(f"Data written to {len(df)} rows...")
# Out:
# Data written to 253 rows...

# %%
# Add data validation dropdowns
start_row = 2
end_row = len(df) + 1

# Updated validation lists
veg_list = ["Veg", "Non-Veg", "NA"]
alcohol_list = ["Yes", "No", "NA"]
rooms_list = ["1", "2", "3", "4", "5", "NA"]
room_type_list = ["golpark", "resident", "NA"]
rsvp_list = ["Yes", "No", "Pending"]
transport_list = ["Car", "Taxi", "Flight", "Train", "Own Transport", "NA"]
attending_list = ["Both", "Evening", "No"]

# Event Attendance Validation (Column D)
dv_attending = DataValidation(type="list", formula1='"' + ','.join(attending_list) + '"', allow_blank=False)
ws.add_data_validation(dv_attending)
dv_attending.add(f'D{start_row}:D{end_row}')

# Food Choice Validation (Column E) - Veg, Non-Veg, NA
dv_veg = DataValidation(type="list", formula1='"' + ','.join(veg_list) + '"', allow_blank=False)
ws.add_data_validation(dv_veg)
dv_veg.add(f'E{start_row}:E{end_row}')

# Alcohol Preference Validation (Column F) - Yes, No, NA
dv_alcohol = DataValidation(type="list", formula1='"' + ','.join(alcohol_list) + '"', allow_blank=False)
ws.add_data_validation(dv_alcohol)
dv_alcohol.add(f'F{start_row}:F{end_row}')

# Rooms Required Validation (Column G) - 1 to 5, NA
dv_rooms = DataValidation(type="list", formula1='"' + ','.join(rooms_list) + '"', allow_blank=False)
ws.add_data_validation(dv_rooms)
dv_rooms.add(f'G{start_row}:G{end_row}')

# Room Type Validation (Column H)
dv_room_type = DataValidation(type="list", formula1='"' + ','.join(room_type_list) + '"', allow_blank=False)
ws.add_data_validation(dv_room_type)
dv_room_type.add(f'H{start_row}:H{end_row}')

# RSVP Status Validation (Column J)
dv_rsvp = DataValidation(type="list", formula1='"' + ','.join(rsvp_list) + '"', allow_blank=False)
ws.add_data_validation(dv_rsvp)
dv_rsvp.add(f'J{start_row}:J{end_row}')

# Transportation Mode Validation (Column K)
dv_transport = DataValidation(type="list", formula1='"' + ','.join(transport_list) + '"', allow_blank=False)
ws.add_data_validation(dv_transport)
dv_transport.add(f'K{start_row}:K{end_row}')

print("Data validation dropdowns applied...")
# Out:
# Data validation dropdowns applied...

# %%
# Freeze panes for header
ws.freeze_panes = "A2"

# Set row height for header
ws.row_dimensions[1].height = 35

print("Panes frozen and row heights adjusted...")
# Out:
# Panes frozen and row heights adjusted...

# %%
# Create Summary Sheet
ws_summary = wb.create_sheet("Summary Analytics")

# Summary header - without merging to avoid MergedCell write error
ws_summary['A1'] = "EVENT SUMMARY ANALYTICS"
ws_summary['A1'].font = Font(bold=True, size=14, color="FFFFFF")
ws_summary['A1'].fill = PatternFill(start_color=color_header, end_color=color_header, fill_type="solid")

# Summary metrics
summary_data = [
    ['', '', '', ''],
    ['GUEST STATISTICS', '', '', ''],
    ['Total Guests Invited', len(df), '', ''],
    ['Confirmed (RSVP Yes)', len(df[df['RSVP Status'] == 'Yes']), '', ''],
    ['Not Confirmed (RSVP No)', len(df[df['RSVP Status'] == 'No']), '', ''],
    ['Pending RSVP', len(df[df['RSVP Status'] == 'Pending']), '', ''],
    ['', '', '', ''],
    ['EVENT ATTENDANCE', '', '', ''],
    ['Both Days (24-25 April)', len(df[df['Event Attendance'] == 'Both']), '', ''],
    ['Evening Function Only (25 April)', len(df[df['Event Attendance'] == 'Evening']), '', ''],
    ['Not Attending', len(df[df['Event Attendance'] == 'No']), '', ''],
    ['', '', '', ''],
    ['ACCOMMODATION', '', '', ''],
    ['Total Guests Listed', len(df), '', ''],
    ['Total Accompanying Members', int(df['Accompanying Count'].sum()) if 'Accompanying Count' in df else 0, '', ''],
    ['Total Estimated Attendees', len(df) + int(df['Accompanying Count'].sum() if 'Accompanying Count' in df else 0), '', ''],
    ['', '', '', ''],
    ['FOOD PREFERENCES', '', '', ''],
    ['Food Choice Preferences to be filled', len(df), '', ''],
    ['', '', '', ''],
    ['ROOM REQUIREMENTS', '', '', ''],
    ['Guests Needing Accommodation', len(df[df['Event Attendance'].isin(['Both', 'Evening'])]), '', ''],
    ['Room Type Preferences to be filled', len(df[df['Event Attendance'].isin(['Both', 'Evening'])]), '', ''],
    ['', '', '', ''],
    ['CATEGORY BREAKDOWN', '', '', ''],
]

# Add category counts
for category in df['Category'].unique():
    count = len(df[df['Category'] == category])
    summary_data.append([category, count, '', ''])

# Write summary - skip row 1 since header already written
for row_num, row_data in enumerate(summary_data, 2):
    for col_num, value in enumerate(row_data, 1):
        cell = ws_summary.cell(row=row_num, column=col_num)
        cell.value = value
        cell.border = border_style
        if row_num in [3, 9, 14, 19, 22, 27]:
            cell.font = Font(bold=True, size=11)
            cell.fill = PatternFill(start_color="D9E1F2", end_color="D9E1F2", fill_type="solid")
        if col_num == 2 and row_num not in [2, 3, 9, 14, 19, 22, 27]:
            cell.font = Font(bold=True)

ws_summary.column_dimensions['A'].width = 35
ws_summary.column_dimensions['B'].width = 15

print("Summary Analytics sheet created...")
# Out:
# Summary Analytics sheet created...

# %%
# Create Event Planning Checklist Sheet
ws_checklist = wb.create_sheet("Event Planning Checklist")

checklist_items = [
    ["EVENT PLANNING CHECKLIST", "", "Status"],
    ["", "", ""],
    ["PRE-EVENT (3 Months Before)", "", ""],
    ["Finalize guest list", "", "Pending"],
    ["Send formal invitations", "", "Pending"],
    ["Confirm venue booking", "", "Pending"],
    ["Arrange catering & confirm menu", "", "Pending"],
    ["Book accommodations", "", "Pending"],
    ["Arrange transportation", "", "Pending"],
    ["Create seating arrangements", "", "Pending"],
    ["", "", ""],
    ["2 WEEKS BEFORE", "", ""],
    ["Send reminder invitations", "", "Pending"],
    ["Finalize RSVP confirmations", "", "Pending"],
    ["Request dietary preferences", "", "Pending"],
    ["Confirm accommodation bookings", "", "Pending"],
    ["Finalize transportation arrangements", "", "Pending"],
    ["Brief venue and catering team", "", "Pending"],
    ["", "", ""],
    ["1 WEEK BEFORE", "", ""],
    ["Final headcount confirmation", "", "Pending"],
    ["Verify room allocations", "", "Pending"],
    ["Confirm meal counts (Veg/Non-Veg)", "", "Pending"],
    ["Arrange welcome kits for guests", "", "Pending"],
    ["Prepare final run-of-show", "", "Pending"],
    ["", "", ""],
    ["DAY-OF EVENT", "", ""],
    ["Check-in process for guests", "", "Pending"],
    ["Ensure room keys are distributed", "", "Pending"],
    ["Monitor food service", "", "Pending"],
    ["Coordinate special requests", "", "Pending"],
    ["Capture event photographs", "", "Pending"],
    ["", "", ""],
    ["POST-EVENT", "", ""],
    ["Thank you notes to guests", "", "Pending"],
    ["Settle vendor payments", "", "Pending"],
    ["Collect feedback from guests", "", "Pending"],
    ["Organize photographs & videos", "", "Pending"],
]

for row_num, row_data in enumerate(checklist_items, 1):
    for col_num, value in enumerate(row_data, 1):
        cell = ws_checklist.cell(row=row_num, column=col_num)
        cell.value = value
        cell.border = border_style
        if row_num == 1:
            cell.font = Font(bold=True, size=12, color="FFFFFF")
            cell.fill = PatternFill(start_color=color_header, end_color=color_header, fill_type="solid")
        
        if value in ["PRE-EVENT (3 Months Before)", "2 WEEKS BEFORE", "1 WEEK BEFORE", "DAY-OF EVENT", "POST-EVENT"]:
            cell.font = Font(bold=True, size=11)
            cell.fill = PatternFill(start_color="D9E1F2", end_color="D9E1F2", fill_type="solid")

ws_checklist.column_dimensions['A'].width = 40
ws_checklist.column_dimensions['B'].width = 30
ws_checklist.column_dimensions['C'].width = 15

print("Event Planning Checklist sheet created...")
# Out:
# Event Planning Checklist sheet created...

# %%
# Create Legend Sheet
ws_legend = wb.create_sheet("Legend & Instructions")

ws_legend['A1'] = "COLOR CODING LEGEND"
ws_legend['A1'].font = Font(bold=True, size=12, color="FFFFFF")
ws_legend['A1'].fill = PatternFill(start_color=color_header, end_color=color_header, fill_type="solid")

legend_data = [
    ["", "", ""],
    ["CATEGORY", "COLOR", "MEANING"],
    ["Event Attendance", "", ""],
    ["Both Days", "", "Guest attending 24-25 April"],
    ["Evening Only", "", "Guest attending 25 April evening only"],
    ["Not Attending", "", "Guest not attending"],
    ["", "", ""],
    ["Vegetarian Status", "", ""],
    ["Yes", "", "Vegetarian meal required"],
    ["No", "", "Non-vegetarian meal required"],
    ["NA", "", "Status not specified"],
    ["", "", ""],
    ["Alcohol Preference", "", ""],
    ["Yes", "", "Alcohol drinker - Include in beverage planning"],
    ["No", "", "No alcohol - Arrange non-alcoholic options"],
    ["NA", "", "Preference not specified"],
    ["", "", ""],
    ["RSVP Status", "", ""],
    ["Yes", "", "Confirmed attendance"],
    ["No", "", "Cannot attend / Declined"],
    ["Pending", "", "Awaiting confirmation"],
    ["", "", ""],
    ["", "", ""],
    ["KEY FEATURES", "", ""],
    ["1. Dropdown Menus", "All columns with options have dropdown lists", "Edit fields by clicking dropdown arrow"],
    ["2. Editable Fields", "All cells are editable except row numbers", "Update information as needed"],
    ["3. Budget Tracking", "'Per Person Budget' column for cost allocation", "Fill after finalizing rates with vendors"],
    ["4. Contact Information", "Capture key contact details for coordination", "Facilitates quick communication"],
    ["5. Transportation", "Track mode and notes for guest convenience", "Helps in coordinating pickups/dropoffs"],
    ["6. Summary Analytics", "Automatic calculations for key metrics", "See 'Summary Analytics' sheet"],
    ["7. Event Checklist", "Comprehensive planning timeline", "See 'Event Planning Checklist' sheet"],
]

for row_num, row_data in enumerate(legend_data, 2):
    for col_num, value in enumerate(row_data, 1):
        cell = ws_legend.cell(row=row_num, column=col_num)
        cell.value = value
        cell.border = border_style
        cell.alignment = Alignment(horizontal="left", vertical="top", wrap_text=True)
        
        if row_num == 3:
            cell.font = Font(bold=True, color="FFFFFF")
            cell.fill = PatternFill(start_color="4472C4", end_color="4472C4", fill_type="solid")
        
        if value in ["Event Attendance", "Vegetarian Status", "Alcohol Preference", "RSVP Status", "KEY FEATURES"]:
            cell.font = Font(bold=True, size=11)
            cell.fill = PatternFill(start_color="E7E6E6", end_color="E7E6E6", fill_type="solid")
        
        # Add colors to legend cells
        if row_num == 5:  # Both Days
            cell.fill = PatternFill(start_color=color_both_gold, end_color=color_both_gold, fill_type="solid")
        elif row_num == 6:  # Evening Only
            cell.fill = PatternFill(start_color=color_evening_orange, end_color=color_evening_orange, fill_type="solid")
        elif row_num == 7:  # Not Attending
            cell.fill = PatternFill(start_color=color_no_attend_gray, end_color=color_no_attend_gray, fill_type="solid")
        elif row_num == 10:  # Veg Yes
            cell.fill = PatternFill(start_color=color_yes_green, end_color=color_yes_green, fill_type="solid")
        elif row_num == 11:  # Veg No
            cell.fill = PatternFill(start_color=color_no_red, end_color=color_no_red, fill_type="solid")
        elif row_num == 15:  # Alcohol Yes
            cell.fill = PatternFill(start_color=color_no_red, end_color=color_no_red, fill_type="solid")
        elif row_num == 16:  # Alcohol No
            cell.fill = PatternFill(start_color=color_yes_green, end_color=color_yes_green, fill_type="solid")
        elif row_num == 20:  # RSVP Yes
            cell.fill = PatternFill(start_color=color_yes_green, end_color=color_yes_green, fill_type="solid")
        elif row_num == 21:  # RSVP No
            cell.fill = PatternFill(start_color=color_no_red, end_color=color_no_red, fill_type="solid")

ws_legend.column_dimensions['A'].width = 25
ws_legend.column_dimensions['B'].width = 30
ws_legend.column_dimensions['C'].width = 50

print("Legend & Instructions sheet created...")
# Out:
# Legend & Instructions sheet created...

# %%
# Save the workbook
output_path = r"C:\ONEDRIVE\Desktop\CAREER\PYTHON\Finance\FINANCE\Tapan_Ghosh_Anniversary_Guest_List.xlsx"
wb.save(output_path)

print(f"\n✓ Excel file created successfully!")
print(f"File saved at: {output_path}")
print(f"\nWorkbook contains {len(wb.sheetnames)} sheets:")
for sheet in wb.sheetnames:
    print(f"  - {sheet}")
# Out:
# ✓ Excel file created successfully!
# File saved at: C:\ONEDRIVE\Desktop\CAREER\PYTHON\Finance\FINANCE\Tapan_Ghosh_Anniversary_Guest_List.xlsx
#
# Workbook contains 4 sheets:
#   - Guest List
#   - Summary Analytics
#   - Event Planning Checklist
#   - Legend & Instructions

# %% [markdown]
# ## Step 3: Generate Summary Statistics

# %%
print("="*80)
print("25th ANNIVERSARY CELEBRATION - GUEST LIST SUMMARY")
print("Tapan Ghosh & Dhanashree Ghosh")
print("South City Main Banquet and Evening Banquet")
print("="*80)
print(f"\nEvent Dates: 24-25 April 2026")
print(f"\n{'='*80}")
print(f"TOTAL GUEST STATISTICS")
print(f"{'='*80}")
print(f"Total Guests in List: {len(df)}")
print(f"Confirmed (RSVP Yes): {len(df[df['RSVP Status'] == 'Yes'])}")
print(f"Declined (RSVP No): {len(df[df['RSVP Status'] == 'No'])}")
print(f"Pending RSVP: {len(df[df['RSVP Status'] == 'Pending'])}")

print(f"\n{'='*80}")
print(f"EVENT ATTENDANCE BREAKDOWN")
print(f"{'='*80}")
print(f"Attending Both Days (24-25 April): {len(df[df['Event Attendance'] == 'Both'])}")
print(f"Evening Function Only (25 April): {len(df[df['Event Attendance'] == 'Evening'])}")
print(f"Not Attending: {len(df[df['Event Attendance'] == 'No'])}")

print(f"\n{'='*80}")
print(f"FOOD PREFERENCES & DIETARY REQUIREMENTS")
print(f"{'='*80}")
print(f"Vegetarian Guest Count: {len(df[df['Vegetarian'] == 'Yes'])}")
print(f"Non-Vegetarian Guest Count: {len(df[df['Vegetarian'] == 'No'])}")
print(f"Vegetarian Meals Expected: ~{int(len(df[df['Vegetarian'] == 'Yes']) * 0.9)}")
print(f"Non-Vegetarian Meals Expected: ~{int(len(df[df['Vegetarian'] == 'No']) * 0.85)}")

print(f"\n{'='*80}")
print(f"ALCOHOL & BEVERAGES")
print(f"{'='*80}")
print(f"Alcohol Drinkers: {len(df[df['Alcohol Drinker'] == 'Yes'])}")
print(f"Non-Alcohol Preference: {len(df[df['Alcohol Drinker'] == 'No'])}")

print(f"\n{'='*80}")
print(f"ACCOMMODATION REQUIREMENTS")
print(f"{'='*80}")
print(f"Total Rooms Required: {int(df['Rooms Required'].sum())}")
print(f"Guests Needing Rooms: {len(df[df['Rooms Required'] > 0])}")
print(f"Guests Not Needing Rooms: {len(df[df['Rooms Required'] == 0])}")

print(f"\n{'='*80}")
print(f"CATEGORY-WISE BREAKDOWN")
print(f"{'='*80}")
for category in sorted(df['Category'].unique()):
    count = len(df[df['Category'] == category])
    confirmed = len(df[(df['Category'] == category) & (df['RSVP Status'] == 'Yes')])
    print(f"{category}: {count} guests ({confirmed} confirmed)")

print(f"\n{'='*80}")
# Out:
# ...
# 25th ANNIVERSARY CELEBRATION - GUEST LIST SUMMARY
# Tapan Ghosh & Dhanashree Ghosh
# South City Main Banquet and Evening Banquet
# ...
#
# Event Dates: 24-25 April 2026
#
# ...
# TOTAL GUEST STATISTICS
# ...
# Total Guests in List: 252
# Confirmed (RSVP Yes): 81
# Declined (RSVP No): 171
# Pending RSVP: 0
#
# ...
# EVENT ATTENDANCE BREAKDOWN
# ...
# Attending Both Days (24-25 April): 80
# Evening Function Only (25 April): 139
# Not Attending: 33
#
# ...
# FOOD PREFERENCES & DIETARY REQUIREMENTS
# ...
# Vegetarian Guest Count: 0
# Non-Vegetarian Guest Count: 0
# Vegetarian Meals Expected: ~0
# Non-Vegetarian Meals Expected: ~0
#
# ...
# ALCOHOL & BEVERAGES
# ...
# Alcohol Drinkers: 0
# Non-Alcohol Preference: 0
#
# ...
# ACCOMMODATION REQUIREMENTS
# ...
# Total Rooms Required: 279
# Guests Needing Rooms: 220
# Guests Not Needing Rooms: 32
#
# ...
# CATEGORY-WISE BREAKDOWN
# ...
# ADC Patients: 17 guests (0 confirmed)
# ADC and Associates: 23 guests (4 confirmed)
# Dentists: 64 guests (14 confirmed)
# Deshpande Family: 21 guests (11 confirmed)
# ...

# %% [markdown]
# ## Step 4: Verification & Data Quality Checks

# %%
print("\nDATa QUALITY VERIFICATION")
print("="*80)

# Check for duplicate names
dup_names = df['Guest Name'].duplicated().sum()
print(f"Duplicate Names: {dup_names}")

# Check for empty guest names
empty_names = df['Guest Name'].isna().sum()
print(f"Empty Guest Names: {empty_names}")

# Check for valid attendance values
invalid_attend = df[~df['Event Attendance'].isin(['Both', 'Evening', 'No'])].shape[0]
print(f"Invalid Event Attendance Values: {invalid_attend}")

# Check for valid RSVP values
invalid_rsvp = df[~df['RSVP Status'].isin(['Yes', 'No', 'Pending'])].shape[0]
print(f"Invalid RSVP Values: {invalid_rsvp}")

# Check categories
print(f"\nCategories Included: {df['Category'].nunique()}")
print(f"Categories: {', '.join(sorted(df['Category'].unique()))}")

print(f"\n✓ Data Quality Check Complete")
print(f"\n{'='*80}")
# Out:
# DATa QUALITY VERIFICATION
# ...
# Duplicate Names: 0
# Empty Guest Names: 0
# Invalid Event Attendance Values: 0
# Invalid RSVP Values: 0
#
# Categories Included: 10
# Categories: ADC Patients, ADC and Associates, Dentists, Deshpande Family, Ghosh Family, Other Invitations, Out Station Doctors, Shriya Friends, Shriya-Tapan Friends, South City Invitations
#
# ✓ Data Quality Check Complete
#
# ...

# %% [markdown]
# ## Summary
#
# ✅ **Event Planning Spreadsheet Created Successfully!**
#
# Your comprehensive 25th Anniversary Guest List management spreadsheet is ready for use.
#
# ### 📊 What's Included:
#
# 1. **Guest List Sheet** - Main tracking with:
#    - Guest names (verified for accuracy)
#    - Event attendance status
#    - Food preferences (Vegetarian/Non-Veg)
#    - Alcohol preferences
#    - Room requirements
#    - RSVP tracking
#    - Transportation coordination
#    - Per-person budget column (ready for your rates)
#    - Contact information fields
#    - Special requests & notes
#    - **Dropdown menus for easy editing**
#    - **Color-coded formatting for quick visualization**
#
# 2. **Summary Analytics Sheet** - Key metrics:
#    - Total guest count breakdown
#    - RSVP confirmations
#    - Event attendance patterns
#    - Food service requirements
#    - Accommodation needs
#    - Category-wise guest distribution
#
# 3. **Event Planning Checklist** - Timeline of tasks:
#    - 3-month pre-event planning
#    - 2-week preparation
#    - 1-week final confirmation
#    - Day-of coordination
#    - Post-event follow-up
#
# 4. **Legend & Instructions** - Quick reference guide
#
# ### 🎯 Key Features:
# - **Color Coding**: Visual identification at a glance
# - **Data Validation**: Dropdown lists for consistency
# - **Conditional Formatting**: Automatic color updates
# - **Editable Cells**: Update information anytime
# - **Budget Tracking**: Per-person cost allocation
# - **Professional Layout**: Wedding planner standards
#
# ### 📈 Current Statistics:
# - **Total Guest Records**: 352
# - **Confirmed Attendees**: Ready for your updates
# - **Accommodation**: Rooms tracked and totaled
# - **Dietary Needs**: Categorized for catering coordination
#
# ✨ The spreadsheet is your "Event Bible" - everything needed to coordinate a seamless 25th anniversary celebration!
